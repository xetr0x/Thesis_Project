# %%
import numpy as np
import pandas as pd
import pickle as pckl
import torch as torch
from torch import nn as nn
from torch import optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
df = pd.read_csv('data_fixed.csv', delimiter = ';')
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def fix_timeseries(df):
    df_new = df.copy()

    df_new['hour'] = df['Timestamp'].dt.hour
    df_new['minute'] = df['Timestamp'].dt.minute
    df_new['second'] = df['Timestamp'].dt.second

    df_new['sin_h'] = np.sin(2* np.pi * df_new['hour']/24)
    df_new['cos_h'] = np.cos(2* np.pi * df_new['hour']/24)
    df_new['sin_m'] = np.sin(2* np.pi * df_new['minute']/60)
    df_new['cos_m'] = np.cos(2* np.pi * df_new['minute']/60)
    df_new['sin_s'] = np.sin(2* np.pi * df_new['second']/60)
    df_new['cos_s'] = np.cos(2* np.pi * df_new['second']/60)
    
    return df_new

# %%
def prep_data(df, batch_size = 50):
    df_copy = df.copy()

    df_with_time = fix_timeseries(df_copy)
    timestamps = df_with_time['Timestamp'].values
    
    numeric_df = df_with_time.copy()
    error_values = ['#NAMN', '#NAMN?', '#NAME?', '#DIV/0!', '#N/A', '#NULL!', '#NUM!', '#REF!', '#VALUE!']
    
    for col in numeric_df.columns:
        
        if numeric_df[col].dtype == 'object' or numeric_df[col].astype(str).str.contains('#').any():
            numeric_df[col] = numeric_df[col].astype(str).replace(error_values, '1e9')
            numeric_df[col] = pd.to_numeric(numeric_df[col], errors='coerce')
    
    
    for col in numeric_df.columns:
        if pd.api.types.is_numeric_dtype(numeric_df[col]):
            valid_values = numeric_df[col][~np.isinf(numeric_df[col])]
            if len(valid_values) > 0:
                max_value = valid_values.max()
                numeric_df[col] = numeric_df[col].replace([np.inf, -np.inf], max_value)
    numeric_df = numeric_df.fillna(numeric_df.mean(numeric_only=True))
    
    numeric_df = numeric_df.drop(['Timestamp', 'hour', 'minute', 'second'], axis=1, errors='ignore')
    
    feature_names = numeric_df.columns.tolist()
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(numeric_df)
    test_ratio = 0.2
    train_size = int((1 - test_ratio) * len(data_scaled))
    X_train = data_scaled[:train_size]
    X_test = data_scaled[train_size:]
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    X_train_tensor = torch.FloatTensor(X_train).to(device)
    X_test_tensor = torch.FloatTensor(X_test).to(device)

    train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
    
    train_loader = DataLoader(train_dataset, batch_size = batch_size)
    test_loader = DataLoader(test_dataset, batch_size = batch_size)

    return train_loader, timestamps,feature_names,test_loader

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.output_layer = nn.Linear(hidden_size, output_size)
        
    def forward(self, x):
        x = x.unsqueeze(1)
        batch_size = x.size(0)
        
        hidden_states = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(self.device)
        cell_states = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(self.device)
        
        out, _ = self.lstm(x, (hidden_states, cell_states))
        
        out = self.output_layer(out[:, -1, :])
        return out

# %%
def train_lstm(epochs, model, train_loader, test_loader=None, weight_decay=1e-4, early_stop_patience=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    model = model.to(device)
    
    
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    
    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    
    train_losses = []
    val_losses = []
    
    for epoch in range(epochs):
        running_loss = 0.0
        batch_count = 0
        
        model.train()
        data_iterator = iter(train_loader)
        has_batches = False
        
        while True:
            try:
                data = next(data_iterator)
                has_batches = True
                inputs, targets = data
                
                inputs = inputs.to(device)
                targets = targets.to(device)
                
                optimizer.zero_grad()
                
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                running_loss += loss.item()
                batch_count += 1
                
            except StopIteration:
                break
            except Exception as e:
                print(f"Error processing batch: {str(e)}")
                print(f"Input shape: {inputs.shape if 'inputs' in locals() else 'unknown'}")
                break
        
        if not has_batches:
            print(f"Epoch {epoch+1}/{epochs}: No data was processed! DataLoader is empty.")
            break
        
        if batch_count > 0:
            epoch_loss = running_loss / batch_count
            train_losses.append(epoch_loss)
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.6f}, Batches: {batch_count}")
        else:
            print(f"Epoch {epoch+1}/{epochs}: Processed 0 batches.")
            break
            
        if test_loader is not None:
            model.eval()
            val_loss = 0.0
            val_batch_count = 0
            
            with torch.no_grad():
                for val_inputs, val_targets in test_loader:
                    try:
                        val_inputs = val_inputs.to(device)
                        val_targets = val_targets.to(device)
                        
                        val_outputs = model(val_inputs)
                        batch_loss = criterion(val_outputs, val_targets)
                        
                        val_loss += batch_loss.item()
                        val_batch_count += 1
                    except Exception as e:
                        print(f"Error in validation: {str(e)}")
                        print(f"Validation input shape: {val_inputs.shape if 'val_inputs' in locals() else 'unknown'}")
                        continue
            
            if val_batch_count > 0:
                avg_val_loss = val_loss / val_batch_count
                val_losses.append(avg_val_loss)
                print(f"Validation Loss: {avg_val_loss:.6f}")
                
                if avg_val_loss < best_loss:
                    best_loss = avg_val_loss
                    patience_counter = 0
                    
                    best_model_state = model.state_dict().copy()
                    print(f"New best model saved with validation loss: {best_loss:.6f}")
                else:
                    patience_counter += 1
                    print(f"Early stopping patience: {patience_counter}/{early_stop_patience}")
                    if patience_counter >= early_stop_patience:
                        print(f"Early stopping triggered after {epoch+1} epochs")
                        
                        if best_model_state is not None:
                            model.load_state_dict(best_model_state)
                        break
    
    if test_loader is not None and best_model_state is not None:
        model.load_state_dict(best_model_state)
    
    history = {
        'train_loss': train_losses,
        'val_loss': val_losses if test_loader is not None else None
    }
    
    return model, history

# %%
epoch = 100
batch_size = 50
input_size = 12
hidden_size = 512
num_layers = 4
output_size = 12

# %%
train_loader, timestamps,feature_names,test_loader= prep_data(df, batch_size)

# %%
model = LSTM(input_size, hidden_size, num_layers)

# %%
trained_model,history = train_lstm(epoch, model, train_loader,test_loader)
# Out:
# Epoch 1/100, Train Loss: 0.366151, Batches: 846
# Validation Loss: 1.253997
# New best model saved with validation loss: 1.253997
# Epoch 2/100, Train Loss: 0.318745, Batches: 846
# Validation Loss: 1.583517
# Early stopping patience: 1/10
# Epoch 3/100, Train Loss: 0.303786, Batches: 846
# Validation Loss: 1.082001
# New best model saved with validation loss: 1.082001
# Epoch 4/100, Train Loss: 0.283127, Batches: 846
# Validation Loss: 1.334065
# Early stopping patience: 1/10
# Epoch 5/100, Train Loss: 0.235475, Batches: 846
# Validation Loss: 1.036759
# New best model saved with validation loss: 1.036759
# Epoch 6/100, Train Loss: 0.231736, Batches: 846
# Validation Loss: 1.023627
# New best model saved with validation loss: 1.023627
# Epoch 7/100, Train Loss: 0.234959, Batches: 846
# Validation Loss: 0.940576
# New best model saved with validation loss: 0.940576
# Epoch 8/100, Train Loss: 0.202023, Batches: 846
# Validation Loss: 1.140190
# Early stopping patience: 1/10
# Epoch 9/100, Train Loss: 0.228081, Batches: 846
# Validation Loss: 3.056971
# Early stopping patience: 2/10
# Epoch 10/100, Train Loss: 0.200658, Batches: 846
# Validation Loss: 1.422523
# Early stopping patience: 3/10
# Epoch 11/100, Train Loss: 0.170584, Batches: 846
# Validation Loss: 1.170671
# Early stopping patience: 4/10
# Epoch 12/100, Train Loss: 0.175757, Batches: 846
# Validation Loss: 0.893058
# New best model saved with validation loss: 0.893058
# Epoch 13/100, Train Loss: 0.152163, Batches: 846
# Validation Loss: 1.265370
# Early stopping patience: 1/10
# Epoch 14/100, Train Loss: 0.174517, Batches: 846
# Validation Loss: 0.865759
# New best model saved with validation loss: 0.865759
# Epoch 15/100, Train Loss: 0.144801, Batches: 846
# Validation Loss: 0.870758
# Early stopping patience: 1/10
# Epoch 16/100, Train Loss: 0.184640, Batches: 846
# Validation Loss: 0.827912
# New best model saved with validation loss: 0.827912
# Epoch 17/100, Train Loss: 0.154829, Batches: 846
# Validation Loss: 0.878230
# Early stopping patience: 1/10
# Epoch 18/100, Train Loss: 0.154795, Batches: 846
# Validation Loss: 0.658730
# New best model saved with validation loss: 0.658730
# Epoch 19/100, Train Loss: 0.134331, Batches: 846
# Validation Loss: 0.799287
# Early stopping patience: 1/10
# Epoch 20/100, Train Loss: 0.132741, Batches: 846
# Validation Loss: 0.709351
# Early stopping patience: 2/10
# Epoch 21/100, Train Loss: 0.114543, Batches: 846
# Validation Loss: 0.757893
# Early stopping patience: 3/10
# Epoch 22/100, Train Loss: 0.124739, Batches: 846
# Validation Loss: 0.701631
# Early stopping patience: 4/10
# Epoch 23/100, Train Loss: 0.128233, Batches: 846
# Validation Loss: 0.964026
# Early stopping patience: 5/10
# Epoch 24/100, Train Loss: 0.126236, Batches: 846
# Validation Loss: 0.800322
# Early stopping patience: 6/10
# Epoch 25/100, Train Loss: 0.141597, Batches: 846
# Validation Loss: 0.700075
# Early stopping patience: 7/10
# Epoch 26/100, Train Loss: 0.123391, Batches: 846
# Validation Loss: 0.726548
# Early stopping patience: 8/10
# Epoch 27/100, Train Loss: 0.133405, Batches: 846
# Validation Loss: 0.821139
# Early stopping patience: 9/10
# Epoch 28/100, Train Loss: 0.130598, Batches: 846
# Validation Loss: 0.698101
# Early stopping patience: 10/10
# Early stopping triggered after 28 epochs

# %%
plt.figure(figsize=(10, 6))
plt.plot(history['train_loss'], label='Training Loss')
if history['val_loss'] is not None:
    plt.plot(history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LSTM Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
torch.save(trained_model,'LSTM.sav' )
