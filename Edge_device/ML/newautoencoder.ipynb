# %%
import numpy as np
import pandas as pd
import pickle as pckl
import torch as torch
from torch import nn as nn
from torch import optim as optim
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import joblib

# %%
torch.manual_seed(42)
np.random.seed(42)

# %%
df = pd.read_csv('data_fixed.csv', delimiter = ';')
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
class autoencoder(nn.Module):
    def __init__(self, input_shape, encoding_dim):
        super(autoencoder, self).__init__()

        self.encode = nn.Sequential(
            nn.Linear(input_shape, 64),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.1),
            nn.Linear(64, 32),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.1),
            nn.Linear(32, encoding_dim),
            )

        self.decode = nn.Sequential(
            nn.Linear(encoding_dim, 32),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.1),
            nn.Linear(32, 64),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.1),
            nn.Linear(64, input_shape)
            )

    def forward(self, x):
        x = self.encode(x)
        x = self.decode(x)
        return x

# %%
def fix_timeseries(df):
    df_new = df.copy()

    df_new['hour'] = df['Timestamp'].dt.hour
    df_new['minute'] = df['Timestamp'].dt.minute
    df_new['second'] = df['Timestamp'].dt.second

    df_new['sin_h'] = np.sin(2* np.pi * df_new['hour']/24)
    df_new['cos_h'] = np.cos(2* np.pi * df_new['hour']/24)
    df_new['sin_m'] = np.sin(2* np.pi * df_new['minute']/60)
    df_new['cos_m'] = np.cos(2* np.pi * df_new['minute']/60)
    df_new['sin_s'] = np.sin(2* np.pi * df_new['second']/60)
    df_new['cos_s'] = np.cos(2* np.pi * df_new['second']/60)
    
    return df_new

# %%
def prep_data(df, batch_size = 50):
    df_copy = df.copy()

    df_with_time = fix_timeseries(df_copy)
    timestamps = df_with_time['Timestamp'].values
    
    numeric_df = df_with_time.copy()
    error_values = ['#NAMN', '#NAMN?', '#NAME?', '#DIV/0!', '#N/A', '#NULL!', '#NUM!', '#REF!', '#VALUE!']
    
    for col in numeric_df.columns:
        
        if numeric_df[col].dtype == 'object' or numeric_df[col].astype(str).str.contains('#').any():
            numeric_df[col] = numeric_df[col].astype(str).replace(error_values, '1e9')
            numeric_df[col] = pd.to_numeric(numeric_df[col], errors='coerce')
    
    
    for col in numeric_df.columns:
        if pd.api.types.is_numeric_dtype(numeric_df[col]):
            valid_values = numeric_df[col][~np.isinf(numeric_df[col])]
            if len(valid_values) > 0:
                max_value = valid_values.max()
                numeric_df[col] = numeric_df[col].replace([np.inf, -np.inf], max_value)
    numeric_df = numeric_df.fillna(numeric_df.mean(numeric_only=True))
    
    numeric_df = numeric_df.drop(['Timestamp', 'hour', 'minute', 'second'], axis=1, errors='ignore')
    
    feature_names = numeric_df.columns.tolist()
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(numeric_df)
    test_ratio = 0.2
    train_size = int((1 - test_ratio) * len(data_scaled))
    X_train = data_scaled[:train_size]
    X_test = data_scaled[train_size:]
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    X_train_tensor = torch.FloatTensor(X_train).to(device)
    X_test_tensor = torch.FloatTensor(X_test).to(device)

    train_dataset = TensorDataset(X_train_tensor, X_train_tensor)
    test_dataset = TensorDataset(X_test_tensor, X_test_tensor)
    
    train_loader = DataLoader(train_dataset, batch_size = batch_size)
    test_loader = DataLoader(test_dataset, batch_size = batch_size)

    return train_loader, timestamps,feature_names,test_loader,scaler

# %%
def train_autoencoder(epochs, model, train_loader, test_loader=None, weight_decay=1e-4, early_stop_patience=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    model = model.to(device)
    
   
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=weight_decay)
    criterion = nn.MSELoss()
    
    best_loss = float('inf')
    patience_counter = 0
    best_model_state = None
    
    train_losses = []
    val_losses = []
    
    for epoch in range(epochs):
        
        running_loss = 0.0
        batch_count = 0
        
        model.train() 
        data_iterator = iter(train_loader)
        has_batches = False
        
        while True:
            try:
                data = next(data_iterator)
                has_batches = True
                inputs, targets = data
                
                inputs = inputs.to(device)
                targets = targets.to(device)

                optimizer.zero_grad()
                outputs = model(inputs)

                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                
                running_loss += loss.item()
                batch_count += 1
                
            except StopIteration:
                break
            except Exception as e:
                print(f"Error processing batch: {str(e)}")
                break
        
        if not has_batches:
            print(f"Epoch {epoch+1}/{epochs}: No data was processed! DataLoader is empty.")
            break
        
        if batch_count > 0:
            epoch_loss = running_loss / batch_count
            train_losses.append(epoch_loss)
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.6f}, Batches: {batch_count}")
        else:
            print(f"Epoch {epoch+1}/{epochs}: Processed 0 batches.")
            break

        if test_loader is not None:
            model.eval() 
            val_loss = 0.0
            val_batch_count = 0
            
            with torch.no_grad(): 
                for val_inputs, val_targets in test_loader:
                    val_inputs = val_inputs.to(device)
                    val_targets = val_targets.to(device)
                    
                    val_outputs = model(val_inputs)
                    batch_loss = criterion(val_outputs, val_targets)
                    
                    val_loss += batch_loss.item()
                    val_batch_count += 1
            
            if val_batch_count > 0:
                avg_val_loss = val_loss / val_batch_count
                val_losses.append(avg_val_loss)
                print(f"Validation Loss: {avg_val_loss:.6f}")
                
                if avg_val_loss < best_loss:
                    best_loss = avg_val_loss
                    patience_counter = 0
                    
                    best_model_state = model.state_dict().copy()
                else:
                    patience_counter += 1
                    if patience_counter >= early_stop_patience:
                        print(f"Early stopping triggered after {epoch+1} epochs")
                        
                        if best_model_state is not None:
                            model.load_state_dict(best_model_state)
                        break
    if test_loader is not None and best_model_state is not None:
        model.load_state_dict(best_model_state)
    
    return model

# %%
input_dim = 12
batch_size = 50
epoch = 100
encoding_dim = 10

# %%
train_loader, timestamps,feature_names,test_loader,scaler= prep_data(df, batch_size)

# %%
model = autoencoder(input_dim, encoding_dim)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
trained_model = train_autoencoder(epoch, model, train_loader,test_loader, weight_decay = 1e-4, early_stop_patience = 10)
# Out:
# Epoch 1/100, Train Loss: 0.935381, Batches: 846
# Validation Loss: 1.077201
# Epoch 2/100, Train Loss: 0.705277, Batches: 846
# Validation Loss: 0.963068
# Epoch 3/100, Train Loss: 0.546224, Batches: 846
# Validation Loss: 0.931332
# Epoch 4/100, Train Loss: 0.491398, Batches: 846
# Validation Loss: 0.916885
# Epoch 5/100, Train Loss: 0.456508, Batches: 846
# Validation Loss: 0.902183
# Epoch 6/100, Train Loss: 0.419543, Batches: 846
# Validation Loss: 0.868128
# Epoch 7/100, Train Loss: 0.384434, Batches: 846
# Validation Loss: 0.836574
# Epoch 8/100, Train Loss: 0.361428, Batches: 846
# Validation Loss: 0.819335
# Epoch 9/100, Train Loss: 0.343237, Batches: 846
# Validation Loss: 0.801155
# Epoch 10/100, Train Loss: 0.326024, Batches: 846
# Validation Loss: 0.771740
# Epoch 11/100, Train Loss: 0.309534, Batches: 846
# Validation Loss: 0.744127
# Epoch 12/100, Train Loss: 0.295630, Batches: 846
# Validation Loss: 0.720973
# Epoch 13/100, Train Loss: 0.282658, Batches: 846
# Validation Loss: 0.705522
# Epoch 14/100, Train Loss: 0.270327, Batches: 846
# Validation Loss: 0.690939
# Epoch 15/100, Train Loss: 0.260201, Batches: 846
# Validation Loss: 0.677926
# Epoch 16/100, Train Loss: 0.250702, Batches: 846
# Validation Loss: 0.664882
# Epoch 17/100, Train Loss: 0.242595, Batches: 846
# Validation Loss: 0.650480
# Epoch 18/100, Train Loss: 0.236076, Batches: 846
# Validation Loss: 0.638463
# Epoch 19/100, Train Loss: 0.230214, Batches: 846
# Validation Loss: 0.627349
# Epoch 20/100, Train Loss: 0.225512, Batches: 846
# Validation Loss: 0.616887
# Epoch 21/100, Train Loss: 0.220978, Batches: 846
# Validation Loss: 0.608542
# Epoch 22/100, Train Loss: 0.215704, Batches: 846
# Validation Loss: 0.600043
# Epoch 23/100, Train Loss: 0.212062, Batches: 846
# Validation Loss: 0.591591
# Epoch 24/100, Train Loss: 0.207766, Batches: 846
# Validation Loss: 0.584407
# Epoch 25/100, Train Loss: 0.203905, Batches: 846
# Validation Loss: 0.576576
# Epoch 26/100, Train Loss: 0.200264, Batches: 846
# Validation Loss: 0.569733
# Epoch 27/100, Train Loss: 0.196914, Batches: 846
# Validation Loss: 0.563765
# Epoch 28/100, Train Loss: 0.194183, Batches: 846
# Validation Loss: 0.557717
# Epoch 29/100, Train Loss: 0.190931, Batches: 846
# Validation Loss: 0.553753
# Epoch 30/100, Train Loss: 0.187415, Batches: 846
# Validation Loss: 0.550483
# Epoch 31/100, Train Loss: 0.184323, Batches: 846
# Validation Loss: 0.545782
# Epoch 32/100, Train Loss: 0.181500, Batches: 846
# Validation Loss: 0.543698
# Epoch 33/100, Train Loss: 0.179450, Batches: 846
# Validation Loss: 0.542710
# Epoch 34/100, Train Loss: 0.176429, Batches: 846
# Validation Loss: 0.538986
# Epoch 35/100, Train Loss: 0.174645, Batches: 846
# Validation Loss: 0.539215
# Epoch 36/100, Train Loss: 0.171077, Batches: 846
# Validation Loss: 0.536869
# Epoch 37/100, Train Loss: 0.169573, Batches: 846
# Validation Loss: 0.534508
# Epoch 38/100, Train Loss: 0.165835, Batches: 846
# Validation Loss: 0.533457
# Epoch 39/100, Train Loss: 0.164675, Batches: 846
# Validation Loss: 0.532066
# Epoch 40/100, Train Loss: 0.162792, Batches: 846
# Validation Loss: 0.527048
# Epoch 41/100, Train Loss: 0.160266, Batches: 846
# Validation Loss: 0.525804
# Epoch 42/100, Train Loss: 0.159060, Batches: 846
# Validation Loss: 0.524144
# Epoch 43/100, Train Loss: 0.156900, Batches: 846
# Validation Loss: 0.522163
# Epoch 44/100, Train Loss: 0.155758, Batches: 846
# Validation Loss: 0.518894
# Epoch 45/100, Train Loss: 0.153253, Batches: 846
# Validation Loss: 0.517608
# Epoch 46/100, Train Loss: 0.152106, Batches: 846
# Validation Loss: 0.514006
# Epoch 47/100, Train Loss: 0.149818, Batches: 846
# Validation Loss: 0.513373
# Epoch 48/100, Train Loss: 0.148397, Batches: 846
# Validation Loss: 0.511750
# Epoch 49/100, Train Loss: 0.146652, Batches: 846
# Validation Loss: 0.509678
# Epoch 50/100, Train Loss: 0.145053, Batches: 846
# Validation Loss: 0.508416
# Epoch 51/100, Train Loss: 0.143302, Batches: 846
# Validation Loss: 0.507181
# Epoch 52/100, Train Loss: 0.142184, Batches: 846
# Validation Loss: 0.505792
# Epoch 53/100, Train Loss: 0.141179, Batches: 846
# Validation Loss: 0.504511
# Epoch 54/100, Train Loss: 0.138414, Batches: 846
# Validation Loss: 0.504890
# Epoch 55/100, Train Loss: 0.137415, Batches: 846
# Validation Loss: 0.501085
# Epoch 56/100, Train Loss: 0.137582, Batches: 846
# Validation Loss: 0.501396
# Epoch 57/100, Train Loss: 0.135873, Batches: 846
# Validation Loss: 0.501437
# Epoch 58/100, Train Loss: 0.134329, Batches: 846
# Validation Loss: 0.499168
# Epoch 59/100, Train Loss: 0.132659, Batches: 846
# Validation Loss: 0.499414
# Epoch 60/100, Train Loss: 0.131710, Batches: 846
# Validation Loss: 0.498102
# Epoch 61/100, Train Loss: 0.130052, Batches: 846
# Validation Loss: 0.498167
# Epoch 62/100, Train Loss: 0.128765, Batches: 846
# Validation Loss: 0.495734
# Epoch 63/100, Train Loss: 0.128770, Batches: 846
# Validation Loss: 0.496749
# Epoch 64/100, Train Loss: 0.126841, Batches: 846
# Validation Loss: 0.496012
# Epoch 65/100, Train Loss: 0.125816, Batches: 846
# Validation Loss: 0.495407
# Epoch 66/100, Train Loss: 0.124621, Batches: 846
# Validation Loss: 0.493959
# Epoch 67/100, Train Loss: 0.123542, Batches: 846
# Validation Loss: 0.495252
# Epoch 68/100, Train Loss: 0.122172, Batches: 846
# Validation Loss: 0.494343
# Epoch 69/100, Train Loss: 0.122169, Batches: 846
# Validation Loss: 0.493892
# Epoch 70/100, Train Loss: 0.121393, Batches: 846
# Validation Loss: 0.492449
# Epoch 71/100, Train Loss: 0.118910, Batches: 846
# Validation Loss: 0.492250
# Epoch 72/100, Train Loss: 0.119118, Batches: 846
# Validation Loss: 0.491501
# Epoch 73/100, Train Loss: 0.117602, Batches: 846
# Validation Loss: 0.491893
# Epoch 74/100, Train Loss: 0.117623, Batches: 846
# Validation Loss: 0.489882
# Epoch 75/100, Train Loss: 0.116528, Batches: 846
# Validation Loss: 0.490678
# Epoch 76/100, Train Loss: 0.114902, Batches: 846
# Validation Loss: 0.489554
# Epoch 77/100, Train Loss: 0.114695, Batches: 846
# Validation Loss: 0.489394
# Epoch 78/100, Train Loss: 0.114173, Batches: 846
# Validation Loss: 0.488378
# Epoch 79/100, Train Loss: 0.113044, Batches: 846
# Validation Loss: 0.488133
# Epoch 80/100, Train Loss: 0.112298, Batches: 846
# Validation Loss: 0.488230
# Epoch 81/100, Train Loss: 0.111741, Batches: 846
# Validation Loss: 0.487838
# Epoch 82/100, Train Loss: 0.110675, Batches: 846
# Validation Loss: 0.486764
# Epoch 83/100, Train Loss: 0.110119, Batches: 846
# Validation Loss: 0.486316
# Epoch 84/100, Train Loss: 0.109295, Batches: 846
# Validation Loss: 0.485720
# Epoch 85/100, Train Loss: 0.108524, Batches: 846
# Validation Loss: 0.485727
# Epoch 86/100, Train Loss: 0.107698, Batches: 846
# Validation Loss: 0.484903
# Epoch 87/100, Train Loss: 0.107604, Batches: 846
# Validation Loss: 0.484843
# Epoch 88/100, Train Loss: 0.106974, Batches: 846
# Validation Loss: 0.484164
# Epoch 89/100, Train Loss: 0.105797, Batches: 846
# Validation Loss: 0.483707
# Epoch 90/100, Train Loss: 0.105946, Batches: 846
# Validation Loss: 0.484312
# Epoch 91/100, Train Loss: 0.105557, Batches: 846
# Validation Loss: 0.483906
# Epoch 92/100, Train Loss: 0.104376, Batches: 846
# Validation Loss: 0.483454
# Epoch 93/100, Train Loss: 0.104332, Batches: 846
# Validation Loss: 0.482473
# Epoch 94/100, Train Loss: 0.103577, Batches: 846
# Validation Loss: 0.482699
# Epoch 95/100, Train Loss: 0.103800, Batches: 846
# Validation Loss: 0.482498
# Epoch 96/100, Train Loss: 0.103046, Batches: 846
# Validation Loss: 0.482371
# Epoch 97/100, Train Loss: 0.102048, Batches: 846
# Validation Loss: 0.482110
# Epoch 98/100, Train Loss: 0.101676, Batches: 846
# Validation Loss: 0.482722
# Epoch 99/100, Train Loss: 0.100896, Batches: 846
# Validation Loss: 0.482233
# Epoch 100/100, Train Loss: 0.101345, Batches: 846
# Validation Loss: 0.481863

# %%
filename = 'autoe_model.pth'
scala = 'autoencoderscaler.sav'
torch.save(trained_model.state_dict(), filename)
joblib.dump(scaler,scala)
# Out:
# ['autoencoderscaler.sav']
